# %% [markdown]
# DAY 0 - AI VS ML VS DL VS DS

# %% [markdown]
# AI - Artificial Intelligence ||
# ML - Machine Learning ||
# DL - Deep Learning ||
# DS - Data Science

# %% [markdown]
# VENN DIAGRAM

# %% [markdown]
# ![aivsmlvsdlvsds.webp](attachment:aivsmlvsdlvsds.webp)

# %% [markdown]
# Example for ARTIFICIAL INTELLIGENCE?
#
# Recommendation Systems:
#
# Scenario: Imagine you are on an online shopping platform like Amazon or Netflix.
#
# AI Example: The recommendation system uses AI algorithms to analyze your past preferences, browsing history, and interactions with the platform.
#
# Explanation: If you frequently purchase or watch science fiction movies, the recommendation system, powered by AI, can suggest similar movies or products. This is achieved through machine learning models that predict your preferences based on patterns and similarities found in the data of users with similar interests.

# %% [markdown]
# What is Machine learning and its types?
#
# Machine learning is stats tool using that we can analyze the data,make prediction and forecasting.

# %% [markdown]
# ![supervisedvsunsupervised.webp](attachment:supervisedvsunsupervised.webp)

# %% [markdown]
# Supervised Training Data - classification

# %% [markdown]
# ![day0-supervised-training.png](attachment:day0-supervised-training.png)

# %% [markdown]
# Supervised Testing Data - classification

# %% [markdown]
# ![day0-supervised-testing.png](attachment:day0-supervised-testing.png)

# %% [markdown]
# What is UnSupervised Learning?

# %% [markdown]
# ![day0_clustering.png](attachment:day0_clustering.png)

# %% [markdown]
# UnSupervised Training Data - clustering

# %% [markdown]
# ![clustering_data.png](attachment:clustering_data.png)

# %% [markdown]
# ![day0-clustering-dataset-2.png](attachment:day0-clustering-dataset-2.png)

# %% [markdown]
# What is Deep Learning?
#
# 1.Subset of ML
#
#
#
# 2.To Mimic Human Brain

# %% [markdown]
# ![deeplearning.webp](attachment:deeplearning.webp)
